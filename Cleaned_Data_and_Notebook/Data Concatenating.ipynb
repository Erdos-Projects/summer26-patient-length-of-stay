# %%
import pandas as pd

# %%
df1 = pd.read_csv("PUDF_base1_4q2019_cleaned.csv", low_memory=False)
df2 = pd.read_csv("PUDF_base1_3q2019_cleaned.csv", low_memory=False)
df3 = pd.read_csv("PUDF_base1_2q2019_cleaned.csv", low_memory=False)
df4 = pd.read_csv("PUDF_base1_1q2019_cleaned.csv", low_memory=False)
df5 = pd.read_csv("PUDF_base1_4q2018_cleaned.csv", low_memory=False)
df6 = pd.read_csv("PUDF_base1_3q2018_cleaned.csv", low_memory=False)
df7 = pd.read_csv("PUDF_base1_2q2018_cleaned.csv", low_memory=False)
df8 = pd.read_csv("PUDF_base1_1q2018_cleaned.csv", low_memory=False)
df9 = pd.read_csv("PUDF_base1_4q2017_cleaned.csv", low_memory=False)
df10 = pd.read_csv("PUDF_base1_3q2017_cleaned.csv", low_memory=False)
df11 = pd.read_csv("PUDF_base1_2q2017_cleaned.csv", low_memory=False)
df12 = pd.read_csv("PUDF_base1_1q2017_cleaned.csv", low_memory=False)
df13 = pd.read_csv("PUDF_base1_4q2016_cleaned.csv", low_memory=False)
df14 = pd.read_csv("PUDF_base1_3q2016_cleaned.csv", low_memory=False)
df15 = pd.read_csv("PUDF_base1_2q2016_cleaned.csv", low_memory=False)
df16 = pd.read_csv("PUDF_base1_1q2016_cleaned.csv", low_memory=False)

# %%
df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16], ignore_index=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2642165 entries, 0 to 2642164
# Data columns (total 44 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   RECORD_ID             int64
#  1   DISCHARGE             str
#  2   THCIC_ID              int64
#  3   TYPE_OF_ADMISSION     float64
#  4   SOURCE_OF_ADMISSION   str
#  5   PAT_STATE             str
#  6   PAT_ZIP               int64
#  7   PAT_COUNTRY           str
#  8   PAT_COUNTY            float64
#  9   PUBLIC_HEALTH_REGION  float64
#  10  PAT_STATUS            int64
#  11  SEX_CODE              str
#  12  RACE                  int64
#  13  ETHNICITY             int64
#  14  ADMIT_WEEKDAY         float64
#  15  LENGTH_OF_STAY        float64
#  16  PAT_AGE               int64
#  17  EMERGENCY_DEPT_FLAG   str
#  18  DIAG_CODES_OA         str
#  19  CODE_1                int64
#  20  CODE_2                int64
#  21  CODE_3                int64
#  22  CODE_4                int64
# ...
